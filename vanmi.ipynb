# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\vanmika AG\OneDrive\Desktop\Akira 2\data_cleaning_task (6).csv")
df
# Out:
#    StudentID StudentName  Gender Course AdmissionDate  FeesPaid  Percentage  \
# 0       S001     HARITHA  FEMALE    BCA    01-06-2023     45000          78
# 1       S002       RAHUL    MALE    BCA    02-06-2023     45000          82
# 2       S003       ANITA  FEMALE    BSC    03-06-2023     47000          88
# 3       S004       VINOD    MALE   BCOM    04-06-2023     50000          67
# 4       S005       MEENA  FEMALE    BCA    05-06-2023     45000          91
# 5       S006      SURESH    MALE    BBA    06-06-2023     52000          73
# 6       S007       KAVYA  FEMALE    BBA    07-06-2023     47000          85
# 7       S008       ARJUN    MALE    BCA    08-06-2023     45000          82
# 8       S009       DIVYA  FEMALE    BSC    09-06-2023     47000          89
# 9       S010       RAHUL    MALE    BCA    10-06-2023     45000          82
# 10      S011       ANITA  FEMALE    BSC    11-06-2023     47000          88
# ...

# %%
df.head(10)
# Out:
#   StudentID StudentName  Gender Course AdmissionDate  FeesPaid  Percentage  \
# 0      S001     HARITHA  FEMALE    BCA    01-06-2023     45000          78
# 1      S002       RAHUL    MALE    BCA    02-06-2023     45000          82
# 2      S003       ANITA  FEMALE    BSC    03-06-2023     47000          88
# 3      S004       VINOD    MALE   BCOM    04-06-2023     50000          67
# 4      S005       MEENA  FEMALE    BCA    05-06-2023     45000          91
# 5      S006      SURESH    MALE    BBA    06-06-2023     52000          73
# 6      S007       KAVYA  FEMALE    BBA    07-06-2023     47000          85
# 7      S008       ARJUN    MALE    BCA    08-06-2023     45000          82
# 8      S009       DIVYA  FEMALE    BSC    09-06-2023     47000          89
# 9      S010       RAHUL    MALE    BCA    10-06-2023     45000          82
#
#       City         Phone
# 0  CHENNAI  9.876543e+09
# 1   MUMBAI  9.876501e+09
# 2    DELHI  9.876506e+09
# 3  KOLKATA  9.876512e+09
# ...

# %%
df.tail()
# Out:
#    StudentID StudentName  Gender Course AdmissionDate  FeesPaid  Percentage  \
# 55      S056       ARJUN    MALE    BCA    26-07-2023     45000          76
# 56      S057       DIVYA  FEMALE    BSC    27-07-2023     47000          89
# 57      S058       RAHUL    MALE    BCA    28-07-2023     45000          82
# 58      S059       ANITA  FEMALE    BSC    29-07-2023     47000          88
# 59      S060       VINOD    MALE   BCOM    30-07-2023     50000          67
#
#        City         Phone
# 55  KOLKATA  9.876540e+09
# 56  CHENNAI  9.876551e+09
# 57   MUMBAI  9.876501e+09
# 58    DELHI  9.876506e+09
# 59      KOL           NaN

# %%
df.columns
# Out:
# Index(['StudentID', 'StudentName', 'Gender', 'Course', 'AdmissionDate',
#        'FeesPaid', 'Percentage', 'City', 'Phone'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
import matplotlib.pyplot as plt
plt.bar(df['Gender'],df['FeesPaid'])
# Out:
# <BarContainer object of 57 artists>

# %%
import matplotlib.pyplot as plt
plt.bar(df['Course'],df['FeesPaid'])
# Out:
# <BarContainer object of 57 artists>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(x='Percentage',data=df)
# Out:
# (array([ 7.,  0.,  7.,  6.,  1.,  0.,  9.,  7.,  7., 13.]),
#  array([67. , 69.4, 71.8, 74.2, 76.6, 79. , 81.4, 83.8, 86.2, 88.6, 91. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x='Course',data=df)
# Out:
# <Axes: xlabel='Course', ylabel='count'>

# %%
df['AdmissionDate'] = pd.to_datetime(df['AdmissionDate'],format='%d-%m-%Y')

# %%
df['Month'] = df['AdmissionDate'].dt.month
df
# Out:
#    StudentID StudentName  Gender Course AdmissionDate  FeesPaid  Percentage  \
# 0       S001     HARITHA  FEMALE    BCA    2023-06-01     45000          78
# 1       S002       RAHUL    MALE    BCA    2023-06-02     45000          82
# 2       S003       ANITA  FEMALE    BSC    2023-06-03     47000          88
# 3       S004       VINOD    MALE   BCOM    2023-06-04     50000          67
# 5       S006      SURESH    MALE    BBA    2023-06-06     52000          73
# 6       S007       KAVYA  FEMALE    BBA    2023-06-07     47000          85
# 7       S008       ARJUN    MALE    BCA    2023-06-08     45000          82
# 8       S009       DIVYA  FEMALE    BSC    2023-06-09     47000          89
# 9       S010       RAHUL    MALE    BCA    2023-06-10     45000          82
# 10      S011       ANITA  FEMALE    BSC    2023-06-11     47000          88
# 11      S012       VINOD    MALE   BCOM    2023-06-12     50000          67
# ...

# %%
sns.histplot(x='Month',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Count'>

# %%
sns.countplot(x='Month',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='count'>

# %%
sns.barplot(x='AdmissionDate',y='Month',data=df)
# Out:
# <Axes: xlabel='AdmissionDate', ylabel='Month'>
